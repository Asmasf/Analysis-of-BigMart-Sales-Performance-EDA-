# %% [markdown]
# # 1. Import Data

# %%
import pandas as pd 

df = pd.read_csv("BigMart Sales Data.csv")
df
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
# Simpan kondisi awal dataset untuk laporan akhir
raw_missing = df.isnull().sum().sum()
raw_duplicates = df.duplicated().sum()
raw_columns = df.shape[1]
raw_head = df.head(2).copy() # Ambil contoh data mentah

# %%
data_copy = df.copy()
data_copy
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %% [markdown]
# # 2. Data Exploration

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
list[df.columns]
# Out:
# list[Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales'],
#       dtype='object')]

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df.describe(include="O")
# Out:
#        Item_Identifier Item_Fat_Content              Item_Type  \
# count             8523             8523                   8523
# unique            1559                5                     16
# top              FDW13          Low Fat  Fruits and Vegetables
# freq                10             5089                   1232
#
#        Outlet_Identifier Outlet_Size Outlet_Location_Type        Outlet_Type
# count               8523        6113                 8523               8523
# unique                10           3                    3                  4
# top               OUT027      Medium               Tier 3  Supermarket Type1
# freq                 935        2793                 3350               5577

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# cek jumlah missing values per kolom

df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
# persentase missing values
 
(df.isnull().sum()/len(df))*100
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type          0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
# tampilkan baris yang punya missing values 

df[df.isnull().any(axis=1)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07        19.20          Regular         0.000000
# 7              FDP10          NaN          Low Fat         0.127470
# 8              FDH17        16.20          Regular         0.016687
# 9              FDU28        19.20          Regular         0.094450
# 18             DRI11          NaN          Low Fat         0.034238
# ...              ...          ...              ...              ...
# 8504           NCN18          NaN          Low Fat         0.124111
# 8508           FDW31        11.35          Regular         0.043246
# 8509           FDG45         8.10          Low Fat         0.214306
# 8514           FDA01        15.00          Regular         0.054489
# 8519           FDS36         8.38          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %% [markdown]
# # Cek typo

# %%
# cek typo 

df['Item_Identifier'].value_counts().to_frame()
# Out:
#        Item_Identifier
# FDW13               10
# FDG33               10
# NCY18                9
# FDD38                9
# DRE49                9
# ...                ...
# FDY43                1
# FDQ60                1
# FDO33                1
# DRF48                1
# FDC23                1
#
# [1559 rows x 1 columns]

# %%
df[df["Item_Identifier"] == "FDP10"]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7              FDP10          NaN          Low Fat         0.127470
# 585            FDP10         19.0          Low Fat         0.128066
# 2623           FDP10         19.0          Low Fat         0.128815
# 3382           FDP10         19.0          Low Fat         0.128289
# 4585           FDP10         19.0          Low Fat         0.128090
# 6087           FDP10         19.0          Low Fat         0.128350
# 7883           FDP10         19.0          Low Fat         0.127984
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7     Snack Foods  107.7622            OUT027                       1985
# 585   Snack Foods  104.3622            OUT035                       2004
# 2623  Snack Foods  107.6622            OUT017                       2007
# 3382  Snack Foods  104.9622            OUT049                       1999
# ...

# %%
df['Item_Fat_Content'].value_counts().to_frame()
# Out:
#          Item_Fat_Content
# Low Fat              5089
# Regular              2889
# LF                    316
# reg                   117
# low fat               112

# %%
df['Item_Type'].value_counts().to_frame()
# Out:
#                        Item_Type
# Fruits and Vegetables       1232
# Snack Foods                 1200
# Household                    910
# Frozen Foods                 856
# Dairy                        682
# Canned                       649
# Baking Goods                 648
# Health and Hygiene           520
# Soft Drinks                  445
# Meat                         425
# Breads                       251
# Hard Drinks                  214
# Others                       169
# Starchy Foods                148
# Breakfast                    110
# Seafood                       64

# %%
df['Outlet_Type'].value_counts().to_frame()
# Out:
#                    Outlet_Type
# Supermarket Type1         5577
# Grocery Store             1083
# Supermarket Type3          935
# Supermarket Type2          928

# %%
df['Outlet_Size'].value_counts().to_frame()
# Out:
#         Outlet_Size
# Medium         2793
# Small          2388
# High            932

# %%
df['Outlet_Identifier'].value_counts().to_frame()
# Out:
#         Outlet_Identifier
# OUT027                935
# OUT013                932
# OUT049                930
# OUT046                930
# OUT035                930
# OUT045                929
# OUT018                928
# OUT017                926
# OUT010                555
# OUT019                528

# %%
df['Outlet_Location_Type'].value_counts().to_frame()
# Out:
#         Outlet_Location_Type
# Tier 3                  3350
# Tier 2                  2785
# Tier 1                  2388

# %%
df['Outlet_Type'].value_counts().to_frame()
# Out:
#                    Outlet_Type
# Supermarket Type1         5577
# Grocery Store             1083
# Supermarket Type3          935
# Supermarket Type2          928

# %%
df['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
df['Item_Fat_Content'].unique()
# Out:
# array(['Low Fat', 'Regular', 'low fat', 'LF', 'reg'], dtype=object)

# %%
df['Outlet_Identifier'].unique()
# Out:
# array(['OUT049', 'OUT018', 'OUT010', 'OUT013', 'OUT027', 'OUT045',
#        'OUT017', 'OUT046', 'OUT035', 'OUT019'], dtype=object)

# %%
df['Outlet_Size'].unique()
# Out:
# array(['Medium', nan, 'High', 'Small'], dtype=object)

# %%
# Mencari data pada kolom Item_Visibility- yang visibility-nya nol
visibilitas_nol = data_copy[data_copy['Item_Visibility'] == 0]

# Tampilkan berapa banyak baris yang nol dan contoh datanya
print(f"Jumlah baris dengan visibilitas 0: {len(visibilitas_nol)}")
display(visibilitas_nol[['Item_Identifier', 'Item_Type', 'Item_Visibility']].head())
# Out:
# Jumlah baris dengan visibilitas 0: 526
#    Item_Identifier              Item_Type  Item_Visibility
# 3            FDX07  Fruits and Vegetables              0.0
# 4            NCD19              Household              0.0
# 5            FDP36           Baking Goods              0.0
# 10           FDY07  Fruits and Vegetables              0.0
# 32           FDP33            Snack Foods              0.0

# %%
# Melihat hubungan antara ID outlet dan ukurannya secara keseluruhan

display(pd.crosstab(df['Outlet_Identifier'], df['Outlet_Size']))
# Out:
# Outlet_Size        High  Medium  Small
# Outlet_Identifier
# OUT013              932       0      0
# OUT018                0     928      0
# OUT019                0       0    528
# OUT027                0     935      0
# OUT035                0       0    930
# OUT046                0       0    930
# OUT049                0     930      0

# %%
# Melihat hubungan antara tipe outlet dan ukurannya secara keseluruhan

display(pd.crosstab(df['Outlet_Type'], df['Outlet_Size']))
# Out:
# Outlet_Size        High  Medium  Small
# Outlet_Type
# Grocery Store         0       0    528
# Supermarket Type1   932     930   1860
# Supermarket Type2     0     928      0
# Supermarket Type3     0     935      0

# %%
# Menampilkan semua kolom untuk baris yang Outlet_Size-nya missing value
tabel_lengkap_missing = data_copy[data_copy['Outlet_Size'].isnull()]

# Menampilkan tabel
display(tabel_lengkap_missing)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 3              FDX07       19.200          Regular         0.000000
# 8              FDH17       16.200          Regular         0.016687
# 9              FDU28       19.200          Regular         0.094450
# 25             NCD06       13.000          Low Fat         0.099887
# 28             FDE51        5.925          Regular         0.161467
# ...              ...          ...              ...              ...
# 8502           NCH43        8.420          Low Fat         0.070712
# 8508           FDW31       11.350          Regular         0.043246
# 8509           FDG45        8.100          Low Fat         0.214306
# 8514           FDA01       15.000          Regular         0.054489
# 8519           FDS36        8.380          Regular         0.046982
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 3     Fruits and Vegetables  182.0950            OUT010
# ...

# %%
# 1. Kita filter data yang Outlet_Size-nya kosong (NaN)
data_kosong = data_copy[data_copy['Outlet_Size'].isnull()]

# 2. Kita hitung berapa banyak NaN di setiap kombinasi Tipe dan Lokasi
bukti_tabel = data_kosong.groupby(['Outlet_Type', 'Outlet_Location_Type']).size().reset_index(name='Jumlah_Missing')

# 3. Tampilkan hasilnya
display(bukti_tabel)
# Out:
#          Outlet_Type Outlet_Location_Type  Jumlah_Missing
# 0      Grocery Store               Tier 3             555
# 1  Supermarket Type1               Tier 2            1855

# %%
# Mengelompokkan Tipe dan lokasinya

sebaran_lokasi = data_copy.groupby(['Outlet_Type', 'Outlet_Location_Type']).size().reset_index(name='Jumlah_Toko')
display(sebaran_lokasi)
# Out:
#          Outlet_Type Outlet_Location_Type  Jumlah_Toko
# 0      Grocery Store               Tier 1          528
# 1      Grocery Store               Tier 3          555
# 2  Supermarket Type1               Tier 1         1860
# 3  Supermarket Type1               Tier 2         2785
# 4  Supermarket Type1               Tier 3          932
# 5  Supermarket Type2               Tier 3          928
# 6  Supermarket Type3               Tier 3          935

# %%
# Cek outlet tertentu yang tadinya sering kosong

display(df[df["Outlet_Identifier"] == "OUT045"][["Outlet_Identifier", "Outlet_Type", "Outlet_Size"]].head())
# Out:
#    Outlet_Identifier        Outlet_Type Outlet_Size
# 8             OUT045  Supermarket Type1         NaN
# 33            OUT045  Supermarket Type1         NaN
# 46            OUT045  Supermarket Type1         NaN
# 47            OUT045  Supermarket Type1         NaN
# 56            OUT045  Supermarket Type1         NaN

# %% [markdown]
# # Distribusi data

# %%
# UNTUK OUTLIERS DAN DISTRIBUSI DATA NORMAL/TIDAK NORMAL, SETELAH DATA CLEANING

# %%
import matplotlib.pyplot as plt

# Memastikan data kosong dibuang agar tidak error saat plotting
# bins=5 akan membagi data berat ke dalam 5 kelompok besar
plt.hist(df['Item_Weight'], bins=5, color='#74C69D', edgecolor='black')

plt.title("Distribusi Item Weight")
plt.xlabel("Berat Barang (kg)")
plt.ylabel("Frekuensi")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df['Item_Visibility'], bins=5, color='#74C69D', edgecolor='black')

plt.title("Distribusi Item Visibility")
plt.xlabel("Visibilitas Produk (Persentase Area)")
plt.ylabel("Jumlah Produk")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df['Item_MRP'], bins=5, color='#74C69D', edgecolor='black')

plt.title("Distribusi Item MRP (Harga Produk)")
plt.xlabel("Maximum Retail Price (Harga)")
plt.ylabel("Jumlah Produk")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.hist(df['Item_Outlet_Sales'], bins=5, color='#74C69D', edgecolor='black')

plt.title("Distribusi Item Outlet Sales")
plt.xlabel("Total Penjualan")
plt.ylabel("Frekuensi")
plt.show()

# %% [markdown]
# # 3. Data Cleaning

# %% [markdown]
# ## Input missing value Item_Weight

# %%
# Isi data kosong menggunakan mean

data_copy["Item_Weight"]=data_copy["Item_Weight"].fillna(data_copy["Item_Weight"].mean())

# %%
# cek apakah semua missing value pada Item Weight sudah terisi

print(data_copy['Item_Weight'].isnull().sum())
# Out:
# 0

# %%
# cek ID mana saja yang tidak terinput missing value nya

data_copy[data_copy['Item_Weight'].isnull()]['Item_Identifier'].unique()
# Out:
# array([], dtype=object)

# %%
# pada ID yang missing value nya tidak terisi
# memang tidak ada yang bisa di input karena memang data beratnya yang tidak tersedia untuk produk tersebut.

print(data_copy['Item_Identifier'].isnull().sum())
# Out:
# 0

# %%
# Daftar ID yang ingin diberikan angka 0
id_target = ['FDN52', 'FDK57', 'FDE52', 'FDQ60']

# Mengisi angka 0 hanya untuk ID yang ditentukan
data_copy.loc[df['Item_Identifier'].isin(id_target), 'Item_Weight'] = 0

# Menampilkan tabel ringkasan untuk 4 ID tersebut
hasil_cek = data_copy[data_copy['Item_Identifier'].isin(id_target)][['Item_Identifier', 'Item_Weight']].drop_duplicates()
display(hasil_cek)
# Out:
#      Item_Identifier  Item_Weight
# 927            FDN52          0.0
# 1922           FDK57          0.0
# 4187           FDE52          0.0
# 5022           FDQ60          0.0

# %%
# Cek total missing values untuk seluruh kolom di dataset

print("Ringkasan Missing Values Setelah Imputasi:")
display(data_copy.isnull().sum())
# Out:
# Ringkasan Missing Values Setelah Imputasi:
# Item_Identifier                 0
# Item_Weight                     0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ## Input missing value Outlet_Size

# %%
data_copy["Outlet_Size"].value_counts().to_frame()
# Out:
#         Outlet_Size
# Medium         2793
# Small          2388
# High            932

# %%
# import pandas as pd

# # Cek jumlah missing value sebelum diisi
# print("KONDISI AWAL (MISSING VALUES)")
# print(data_copy[['Outlet_Type', 'Outlet_Location_Type', 'Outlet_Size']].isnull().sum())
# print("-" * 30)

# # Isi data kosong dengan modus berdasarkan kelompok Tipe & Lokasi Toko
# data_copy['Outlet_Size'] = data_copy['Outlet_Size'].fillna(
#     data_copy.groupby(['Outlet_Type', 'Outlet_Location_Type'])['Outlet_Size'].transform(lambda x: x.mode()[0] if not x.mode().empty else "Medium")
# )

# # Pastikan semua missing value sudah terisi (bernilai 0)
# print("KONDISI AKHIR (MISSING VALUES LUNAS)")
# print(data_copy[['Outlet_Type', 'Outlet_Location_Type', 'Outlet_Size']].isnull().sum())

# %%
data_copy["Outlet_Type"][data_copy["Outlet_Size"] == "Medium"].value_counts().to_frame
# Out:
# <bound method Series.to_frame of Supermarket Type3    935
# Supermarket Type1    930
# Supermarket Type2    928
# Name: Outlet_Type, dtype: int64>

# %%
data_copy["Outlet_Type"][data_copy["Outlet_Size"] == "Small"].value_counts().to_frame
# Out:
# <bound method Series.to_frame of Supermarket Type1    1860
# Grocery Store         528
# Name: Outlet_Type, dtype: int64>

# %%
data_copy["Outlet_Type"][data_copy["Outlet_Size"] == "High"].value_counts().to_frame
# Out:
# <bound method Series.to_frame of Supermarket Type1    932
# Name: Outlet_Type, dtype: int64>

# %%
# Input missing value menggunakan modus

data_copy["Outlet_Size"]=data_copy["Outlet_Size"].fillna(data_copy["Outlet_Size"].mode()[0])

# %%
# cek apakah missing value sudah dihandling

data_copy.isnull().sum().to_frame()
# Out:
#                            0
# Item_Identifier            0
# Item_Weight                0
# Item_Fat_Content           0
# Item_Visibility            0
# Item_Type                  0
# Item_MRP                   0
# Outlet_Identifier          0
# Outlet_Establishment_Year  0
# Outlet_Size                0
# Outlet_Location_Type       0
# Outlet_Type                0
# Item_Outlet_Sales          0

# %%
# Cek proporsi setelah diisi

print(data_copy['Outlet_Size'].value_counts(normalize=True))
# Out:
# Medium    0.610466
# Small     0.280183
# High      0.109351
# Name: Outlet_Size, dtype: float64

# %% [markdown]
# # Konsistensi Data

# %%
# Mengganti semua variasi penulisan ke format standar
data_copy['Item_Fat_Content'] = data_copy['Item_Fat_Content'].replace({
    'LF': 'Low Fat',
    'low fat': 'Low Fat',
    'reg': 'Regular'
})

# Cek hasil akhir
print("Hasil setelah dibersihkan:")
print(data_copy['Item_Fat_Content'].value_counts())
# Out:
# Hasil setelah dibersihkan:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
# RAPIDIN TEKS (TEXT CLEANING)

# Ambil semua kolom yang tipenya Kategorikal (Object)
kolom_kategori = data_copy.select_dtypes(include=['object']).columns

# Loop untuk merapikan teks ke Title Case (Huruf depan kapital)
for col in kolom_kategori:
    data_copy[col] = data_copy[col].str.title()

# Khusus untuk Identifier (ID), kita timpa jadi UPPER (Huruf besar semua)
kolom_id = ['Item_Identifier', 'Outlet_Identifier']

for col in kolom_id:
    data_copy[col] = data_copy[col].str.upper()

# VALIDASI HASIL
print("CEK HASIL PERAPIHAN TEKS")
display(data_copy[kolom_kategori].head(10))
# Out:
# CEK HASIL PERAPIHAN TEKS
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits And Vegetables            OUT010
# 4           NCD19          Low Fat              Household            OUT013
# 5           FDP36          Regular           Baking Goods            OUT018
# 6           FDO10          Regular            Snack Foods            OUT013
# 7           FDP10          Low Fat            Snack Foods            OUT027
# 8           FDH17          Regular           Frozen Foods            OUT045
# 9           FDU28          Regular           Frozen Foods            OUT017
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# ...

# %% [markdown]
# # Menghapus duplikat data

# %%
# tidak terdapat data yang duplikat

duplicate = data_copy.duplicated().sum()
print(duplicate)
# Out:
# 0

# %% [markdown]
# # Handling kolom Item_Visibility

# %%
import numpy as np

# Ubah angka 0 menjadi NaN supaya bisa dideteksi oleh fungsi fillna
data_copy['Item_Visibility'] = data_copy['Item_Visibility'].replace(0, np.nan)

# Imputasi nilai NaN dengan Median berdasarkan Item_Type
data_copy['Item_Visibility'] = data_copy['Item_Visibility'].fillna(
    data_copy.groupby('Item_Type')['Item_Visibility'].transform('median')
)

# Validasi akhir: pastikan sudah tidak ada angka 0
print(f"Jumlah baris dengan visibilitas 0 sekarang: {len(data_copy[data_copy['Item_Visibility'] == 0])}")
# Out:
# Jumlah baris dengan visibilitas 0 sekarang: 0

# %%
# Mengisi NaN pada Item_Visibility dengan rata-rata berdasarkan Item_Identifier

data_copy['Item_Visibility'] = data_copy['Item_Visibility'].fillna(
    data_copy.groupby('Item_Identifier')['Item_Visibility'].transform('mean')
)

# %%
data_copy['Item_Visibility'].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Outlier untuk Item_Weight (menggunakan IQR)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# PENGECEKAN OUTLIER: ITEM_WEIGHT
Q1 = data_copy['Item_Weight'].quantile(0.25)
Q3 = data_copy['Item_Weight'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outlier_weight = data_copy[(data_copy['Item_Weight'] < lower) | (data_copy['Item_Weight'] > upper)]

print(f"Jumlah Outlier Item_Weight: {len(outlier_weight)}")

plt.figure(figsize=(8, 2))
sns.boxplot(x=data_copy['Item_Weight'], color='#74C69D')
plt.title('Boxplot Item_Weight')
plt.show()
# Out:
# Jumlah Outlier Item_Weight: 0

# %% [markdown]
# # Outlier untuk Item_Visibility

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# MENAMPILKAN TABEL SEMUA DATA OUTLIER: ITEM_VISIBILITY
Q1 = data_copy['Item_Visibility'].quantile(0.25)
Q3 = data_copy['Item_Visibility'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

# Memasukkan semua data yang di luar pagar ke dalam variabel baru
tabel_outlier_visibility = data_copy[(data_copy['Item_Visibility'] < lower) | (data_copy['Item_Visibility'] > upper)]

# Menampilkan jumlah dan tabelnya
print(f"Ditemukan {len(tabel_outlier_visibility)} baris data outlier.")

plt.figure(figsize=(8, 2))
sns.boxplot(x=data_copy['Item_Visibility'], color='#74C69D')
plt.title('Boxplot Item_Visibility')
plt.show()

print("Berikut adalah tabel lengkap datanya:")

# Pakai display agar muncul dalam bentuk tabel yang bisa di-scroll di notebook
display(tabel_outlier_visibility)
# Out:
# Ditemukan 173 baris data outlier.
# Berikut adalah tabel lengkap datanya:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 49             FDS02    12.857645          Regular         0.255395
# 65             FDC46    17.700000          Low Fat         0.195068
# 83             NCL18    12.857645          Low Fat         0.293418
# 108            DRE60    12.857645          Low Fat         0.278974
# 174            FDI32    17.700000          Low Fat         0.291865
# ...              ...          ...              ...              ...
# 8292           FDF56    12.857645          Regular         0.209163
# 8345           FDY28    12.857645          Regular         0.266397
# 8371           DRA59     8.270000          Regular         0.214125
# 8432           FDI16    14.000000          Regular         0.227261
# 8509           FDG45     8.100000          Low Fat         0.214306
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# ...

# %% [markdown]
# # Outlier untuk Item_MRP

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# --- PENGECEKAN OUTLIER: ITEM_MRP ---
Q1 = data_copy['Item_MRP'].quantile(0.25)
Q3 = data_copy['Item_MRP'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outlier_mrp = data_copy[(data_copy['Item_MRP'] < lower) | (data_copy['Item_MRP'] > upper)]

print(f"Jumlah Outlier Item_MRP: {len(outlier_mrp)}")

plt.figure(figsize=(8, 2))
sns.boxplot(x=data_copy['Item_MRP'], color='#74C69D')
plt.title('Boxplot Item_MRP')
plt.show()
# Out:
# Jumlah Outlier Item_MRP: 0

# %% [markdown]
# # Outlier untuk Item_Outlet_Sales

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# --- PENGECEKAN OUTLIER: ITEM_OUTLET_SALES ---
Q1 = data_copy['Item_Outlet_Sales'].quantile(0.25)
Q3 = data_copy['Item_Outlet_Sales'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outlier_sales = data_copy[(data_copy['Item_Outlet_Sales'] < lower) | (data_copy['Item_Outlet_Sales'] > upper)]

print(f"Jumlah Outlier Item_Outlet_Sales: {len(outlier_sales)}")

plt.figure(figsize=(8, 2))
sns.boxplot(x=data_copy['Item_Outlet_Sales'], color='#74C69D')
plt.title('Boxplot Item_Outlet_Sales')
plt.show()
# Out:
# Jumlah Outlier Item_Outlet_Sales: 186

# %% [markdown]
# # 4. Data Manipulation

# %% [markdown]
# # Distribusi Item_Weight

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# DISTRIBUSI PDF: ITEM_WEIGHT
plt.figure(figsize=(10, 5))
sns.histplot(data_copy['Item_Weight'], kde=True, color='#74C69D', bins=10)

plt.title('Distribusi PDF - Item_Weight', fontsize=14)
plt.xlabel('Berat Barang')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

print(f"Skewness Item_Weight: {data_copy['Item_Weight'].skew():.2f}")
# Out:
# Skewness Item_Weight: 0.08

# %% [markdown]
# # Uji Normalitas Item_Weight

# %%
from scipy.stats import kstest

# Menyiapkan data
data_weight = data_copy['Item_Weight'].dropna()
data_std_weight = (data_weight - data_weight.mean()) / data_weight.std()

# Uji Kolmogorov-Smirnov
stat, p_value = kstest(data_std_weight, 'norm')

print("UJI KOLMOGOROV-SMIRNOV: ITEM_WEIGHT")
print(f"Statistik K-S: {stat:.4f}")
print(f"P-Value      : {p_value:.4f}")

if p_value > 0.05:
    print("Kesimpulan   : Data Berdistribusi NORMAL")
else:
    print("Kesimpulan   : Data TIDAK NORMAL")
# Out:
# UJI KOLMOGOROV-SMIRNOV: ITEM_WEIGHT
# Statistik K-S: 0.1006
# P-Value      : 0.0000
# Kesimpulan   : Data TIDAK NORMAL

# %% [markdown]
# # Distribusi Item_Visibility

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# DISTRIBUSI PDF: ITEM_VISIBILITY
plt.figure(figsize=(10, 5))
sns.histplot(data_copy['Item_Visibility'], kde=True, color='#74C69D', bins=10)

plt.title('Distribusi PDF - Item_Visibility', fontsize=14)
plt.xlabel('Visibilitas')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

print(f"Skewness Item_Visibility: {data_copy['Item_Visibility'].skew():.2f}")
# Out:
# Skewness Item_Visibility: 1.31

# %% [markdown]
# # Uji Normalitas Item_Visibility

# %%
# Menyiapkan data
data_vis = data_copy['Item_Visibility'].dropna()
data_std_vis = (data_vis - data_vis.mean()) / data_vis.std()

# Uji Kolmogorov-Smirnov
stat, p_value = kstest(data_std_vis, 'norm')

print("UJI KOLMOGOROV-SMIRNOV: ITEM_VISIBILITY")
print(f"Statistik K-S: {stat:.4f}")
print(f"P-Value      : {p_value:.4f}")

if p_value > 0.05:
    print("Kesimpulan   : Data Berdistribusi NORMAL")
else:
    print("Kesimpulan   : Data TIDAK NORMAL")
# Out:
# UJI KOLMOGOROV-SMIRNOV: ITEM_VISIBILITY
# Statistik K-S: 0.1145
# P-Value      : 0.0000
# Kesimpulan   : Data TIDAK NORMAL

# %% [markdown]
# # Distribusi Item_MRP

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# DISTRIBUSI PDF: ITEM_MRP
plt.figure(figsize=(10, 5))
sns.histplot(data_copy['Item_MRP'], kde=True, color='#74C69D', bins=10)

plt.title('Distribusi PDF - Item_MRP', fontsize=14)
plt.xlabel('Harga (MRP)')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

print(f"Skewness Item_MRP: {data_copy['Item_MRP'].skew():.2f}")
# Out:
# Skewness Item_MRP: 0.13

# %% [markdown]
# # Uji Normalitas Item_MRP

# %%
# Menyiapkan data
data_mrp = data_copy['Item_MRP'].dropna()
data_std_mrp = (data_mrp - data_mrp.mean()) / data_mrp.std()

# Uji Kolmogorov-Smirnov
stat, p_value = kstest(data_std_mrp, 'norm')

print("UJI KOLMOGOROV-SMIRNOV: ITEM_MRP")
print(f"Statistik K-S: {stat:.4f}")
print(f"P-Value      : {p_value:.4f}")

if p_value > 0.05:
    print("Kesimpulan   : Data Berdistribusi NORMAL")
else:
    print("Kesimpulan   : Data TIDAK NORMAL")
# Out:
# UJI KOLMOGOROV-SMIRNOV: ITEM_MRP
# Statistik K-S: 0.0456
# P-Value      : 0.0000
# Kesimpulan   : Data TIDAK NORMAL

# %% [markdown]
# # Distribusi Item_Outlet_Sales

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# DISTRIBUSI PDF: ITEM_OUTLET_SALES
plt.figure(figsize=(10, 5))
sns.histplot(data_copy['Item_Outlet_Sales'], kde=True, color='#74C69D', bins=10)

plt.title('Distribusi PDF - Item_Outlet_Sales', fontsize=14)
plt.xlabel('Total Penjualan')
plt.ylabel('Density')
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()

print(f"Skewness Item_Outlet_Sales: {data_copy['Item_Outlet_Sales'].skew():.2f}")
# Out:
# Skewness Item_Outlet_Sales: 1.18

# %% [markdown]
# # Uji Normalitas Item_Outlet_Sales

# %%
# Menyiapkan data
data_sales = data_copy['Item_Outlet_Sales'].dropna()
data_std_sales = (data_sales - data_sales.mean()) / data_sales.std()

# Uji Kolmogorov-Smirnov
stat, p_value = kstest(data_std_sales, 'norm')

print("UJI KOLMOGOROV-SMIRNOV: ITEM_OUTLET_SALES")
print(f"Statistik K-S: {stat:.4f}")
print(f"P-Value      : {p_value:.4f}")

if p_value > 0.05:
    print("Kesimpulan   : Data Berdistribusi NORMAL")
else:
    print("Kesimpulan   : Data TIDAK NORMAL")
# Out:
# UJI KOLMOGOROV-SMIRNOV: ITEM_OUTLET_SALES
# Statistik K-S: 0.1041
# P-Value      : 0.0000
# Kesimpulan   : Data TIDAK NORMAL

# %% [markdown]
# # Handling Outliers dengan RobustScaler

# %%
from sklearn.preprocessing import RobustScaler

# Inisialisasi Scaler yang tahan banting terhadap outliers
scaler = RobustScaler()

# Scaling kolom yang ada outliers-nya
data_copy[['Item_Visibility', 'Item_Outlet_Sales']] = scaler.fit_transform(data_copy[['Item_Visibility', 'Item_Outlet_Sales']])

print("Scaling Selesai! Outliers sudah ditangani dengan RobustScaler.")
# Out:
# Scaling Selesai! Outliers sudah ditangani dengan RobustScaler.

# %%
# Set up figure
plt.figure(figsize=(8, 4))

# Visualisasi SESUDAH Scaling (Setelah RobustScaler)
# Menggunakan warna hijau kalem (#95d5b2) biar kelihatan fresh dan profesional
sns.boxplot(x=data_copy['Item_Visibility'], color='#95d5b2')

plt.title('Boxplot Item_Visibility (After RobustScaler Handling)')
plt.xlabel('Nilai Ter-scale (Robust Units)')
plt.show()

# %%
# Visualisasi After Handling
plt.figure(figsize=(8, 4))
sns.boxplot(x=data_copy['Item_Outlet_Sales'], color='#95d5b2') # Pakai warna merah lembut biar beda dari yang hijau tadi

plt.title('Boxplot Item_Outlet_Sales (After RobustScaler Handling)')
plt.xlabel('Nilai Ter-scale (Robust Units)')
plt.show()

# %% [markdown]
# # Konversi Tipe Data (Type Conversion)

# %%
import pandas as pd

# 1. Ubah kolom teks menjadi tipe 'category'
kategori_kolom = ['Item_Fat_Content', 'Item_Type', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']
data_copy[kategori_kolom] = data_copy[kategori_kolom].astype('category')

# 2. Pastikan kolom angka benar-benar numerik
number_kolom = ['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales']
for col in number_kolom:
    data_copy[col] = pd.to_numeric(data_copy[col], errors='coerce')

# Cek apakah tipenya sudah berubah
data_copy.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat        -0.682717
# 1           DRC01         5.92          Regular        -0.630182
# 2           FDN15        17.50          Low Fat        -0.671127
# 3           FDX07        19.20          Regular         0.012099
# 4           NCD19         8.93          Low Fat        -0.146632
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits And Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data_copy.dtypes
# Out:
# Item_Identifier                object
# Item_Weight                   float64
# Item_Fat_Content             category
# Item_Visibility               float64
# Item_Type                    category
# Item_MRP                      float64
# Outlet_Identifier              object
# Outlet_Establishment_Year       int64
# Outlet_Size                  category
# Outlet_Location_Type         category
# Outlet_Type                  category
# Item_Outlet_Sales             float64
# dtype: object

# %% [markdown]
# # Melakukan Filtering & Sorting

# %% [markdown]
# # Filtering berdasarkan Item_Outlet_Sales

# %%
# 1. Pilih ambang batas (Median agar adil 50:50)
batas_sales = data_copy['Item_Outlet_Sales'].median()

# 2. Filtering Produk yang penjualannya di atas rata-rata (High Performance)
df_filter = data_copy[data_copy['Item_Outlet_Sales'] > batas_sales]

# 3. Cek hasil sederhana
print(f"Batas Penjualan: {batas_sales}")
print(f"Jumlah produk 'High Sales': {len(df_filter)} baris")
df_filter.head()
# Out:
# Batas Penjualan: 0.0
# Jumlah produk 'High Sales': 4258 baris
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0            FDA15     9.300000          Low Fat        -0.682717
# 2            FDN15    17.500000          Low Fat        -0.671127
# 7            FDP10    12.857645          Low Fat         1.129034
# 9            FDU28    19.200000          Regular         0.592118
# 11           FDA03    18.500000          Regular        -0.204400
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 0          Dairy  249.8092            OUT049                       1999
# 2           Meat  141.6180            OUT049                       1999
# 7    Snack Foods  107.7622            OUT027                       1985
# 9   Frozen Foods  187.8214            OUT017                       2007
# 11         Dairy  144.1102            OUT046                       1997
#
# ...

# %% [markdown]
# # Sorting

# %%
# Sorting berdasarkan Item_Outlet_Sales (dari yang terbesar) hanya untuk pengecekan
data_sorted = data_copy.sort_values(by='Item_Outlet_Sales', ascending=False)

# Tampilkan 10 data teratas yang sudah rapi
display(data_sorted.head(10))
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7188           NCE42    12.857645          Low Fat        -0.772088
# 5223           FDQ19    12.857645          Regular        -0.711200
# 1450           FDZ20    12.857645          Low Fat         0.012099
# 4349           FDP33    12.857645          Low Fat         0.500904
# 6541           FDI50    12.857645          Regular        -0.444570
# 4888           FDF39    14.850000          Regular        -0.626656
# 1009           FDU14    12.857645          Low Fat        -0.381301
# 7191           NCH18    12.857645          Low Fat        -0.220966
# 4289           NCM05     6.825000          Low Fat         0.029474
# 7752           FDC17    12.857645          Low Fat        -0.693472
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 7188              Household  234.9958            OUT027
# 5223  Fruits And Vegetables  242.6512            OUT027
# ...

# %% [markdown]
# # Grouping

# %%
# TAHAP GROUPING
# Kita ringkas data_copy berdasarkan Outlet_Type
# Melihat rata-rata penjualan per jenis toko

laporan_per_toko = (
    data_copy
    .groupby('Outlet_Type', as_index=False, observed=False)
    .agg(rata_rata_penjualan = ('Item_Outlet_Sales', 'mean'))
    .sort_values('rata_rata_penjualan', ascending=False)
)

# Tampilkan hasilnya
print("Hasil Grouping (Rata-rata Penjualan per Jenis Toko):")
laporan_per_toko
# Out:
# Hasil Grouping (Rata-rata Penjualan per Jenis Toko):
#          Outlet_Type  rata_rata_penjualan
# 3  Supermarket Type3             0.837965
# 1  Supermarket Type1             0.230189
# 2  Supermarket Type2             0.088736
# 0      Grocery Store            -0.641584

# %% [markdown]
# # Membuat Kolom baru menggunakan Feature Engineering

# %% [raw]
# Membuat variable baru yaitu Variabel Price_Per_Weight.
#
# Dengan membagi Harga Maksimal (MRP) dengan Berat Barang, guna mengukur nilai ekonomis produk dan melihat apakah harga per satuan berat ini memengaruhi keputusan beli konsumen di berbagai tipe toko.

# %%
# Feature Engineering: Menghitung harga per satuan berat
df_feature = data_copy.copy()
df_feature['Price_Per_Weight'] = df_feature['Item_MRP'] / df_feature['Item_Weight']

df_feature[['Item_Identifier', 'Price_Per_Weight']].head()
# Out:
#   Item_Identifier  Price_Per_Weight
# 0           FDA15         26.861204
# 1           DRC01          8.153581
# 2           FDN15          8.092457
# 3           FDX07          9.484115
# 4           NCD19          6.031512

# %%
# Cek nilai statistik setelah scaling

data_copy[['Item_Visibility', 'Item_Outlet_Sales']].describe()
# Out:
#        Item_Visibility  Item_Outlet_Sales
# count      8523.000000        8523.000000
# mean          0.189246           0.170688
# std           0.794390           0.752741
# min          -0.885524          -0.776799
# 25%          -0.405675          -0.423495
# 50%           0.000000           0.000000
# 75%           0.594325           0.576505
# max           4.396046           4.981204

# %% [markdown]
# # Encoding

# %% [markdown]
# # 1. Ordinal Encoding (Untuk Kolom Berjenjang)

# %%
# Encoding untuk Outlet_Size dan Outlet_Location_Type
# Alasan: Kedua kolom ini memiliki urutan logis (kecil ke besar / tingkat lokasi).

mapping_size = {'Small': 0, 'Medium': 1, 'High': 2}
mapping_location = {'Tier 3': 0, 'Tier 2': 1, 'Tier 1': 2}

df_feature['Outlet_Size_Encoded'] = df_feature['Outlet_Size'].map(mapping_size)
df_feature['Outlet_Location_Type_Encoded'] = df_feature['Outlet_Location_Type'].map(mapping_location)

print("Ordinal Encoding Selesai!")
display(df_feature[['Outlet_Size', 'Outlet_Size_Encoded', 'Outlet_Location_Type', 'Outlet_Location_Type_Encoded']].head())
# Out:
# Ordinal Encoding Selesai!
#   Outlet_Size Outlet_Size_Encoded Outlet_Location_Type  \
# 0      Medium                   1               Tier 1
# 1      Medium                   1               Tier 3
# 2      Medium                   1               Tier 1
# 3      Medium                   1               Tier 3
# 4        High                   2               Tier 3
#
#   Outlet_Location_Type_Encoded
# 0                            2
# 1                            0
# 2                            2
# 3                            0
# 4                            0

# %% [markdown]
# # 2. Label Encoding (Untuk Kolom Biner/2 Pilihan)

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# Encoding untuk Item_Fat_Content
# Alasan: Hanya ada dua kategori utama (Low Fat & Regular), jadi cukup diubah jadi 0 dan 1.
df_feature['Item_Fat_Content_Encoded'] = le.fit_transform(df_feature['Item_Fat_Content'])

print("Label Encoding Selesai!")
display(df_feature[['Item_Fat_Content', 'Item_Fat_Content_Encoded']].head())
# Out:
# Label Encoding Selesai!
#   Item_Fat_Content  Item_Fat_Content_Encoded
# 0          Low Fat                         0
# 1          Regular                         1
# 2          Low Fat                         0
# 3          Regular                         1
# 4          Low Fat                         0

# %% [markdown]
# # 3. One-Hot Encoding (Untuk Kolom Setara/Nominal)

# %%
# One-Hot Encoding untuk Item_Type dan Outlet_Type
# Alasan: Jenis barang dan jenis toko tidak memiliki urutan (Daging tidak lebih tinggi dari Sayur).

df_final = pd.get_dummies(df_feature, columns=['Item_Type', 'Outlet_Type'], prefix=['Item', 'Outlet'], dtype=int)

print("One-Hot Encoding Selesai!")

# Menampilkan beberapa kolom hasil encoding
display(df_final.filter(like='Outlet_').head())
# Out:
# One-Hot Encoding Selesai!
#   Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0            OUT049                       1999      Medium
# 1            OUT018                       2009      Medium
# 2            OUT049                       1999      Medium
# 3            OUT010                       1998      Medium
# 4            OUT013                       1987        High
#
#   Outlet_Location_Type  Item_Outlet_Sales Outlet_Size_Encoded  \
# 0               Tier 1           0.856094                   1
# 1               Tier 3          -0.595888                   1
# 2               Tier 1           0.133627                   1
# 3               Tier 3          -0.468429                   1
# 4               Tier 3          -0.352717                   2
#
#   Outlet_Location_Type_Encoded  Outlet_Grocery Store  \
# 0                            2                     0
# 1                            0                     0
# ...

# %% [markdown]
# # Analisis Statistik

# %% [raw]
# H0: Tidak terdapat perbedaan rata-rata penjualan yang signifikan di antara berbagai jenis toko (Grocery Store, Supermarket Type 1, Type 2, dan Type 3).
#
# H1: Terdapat perbedaan rata-rata penjualan yang signifikan di antara jenis-jenis toko tersebut.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 7))

# Cuma ganti palette pakai list warna hijau pastel ini aja ya, Bebs!
sns.boxplot(
    data=data_copy, 
    x='Outlet_Type', 
    y='Item_Outlet_Sales', 
    palette=['#52B788', '#74C69D', '#95D5B2', '#B7E4C7']
)

plt.title('Analisis Pengaruh Jenis Toko terhadap Total Penjualan', fontsize=14)
plt.xlabel('Jenis Toko (Outlet Type)', fontsize=12)
plt.ylabel('Total Penjualan (Scaled)', fontsize=12)
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [raw]
# Analisis Insight: Pengaruh Jenis Toko terhadap Penjualan
#
# - Dominasi Supermarket Type 3: Memiliki performa penjualan tertinggi dengan median dan volume transaksi yang jauh melampaui tipe outlet lainnya.
#
# - Keterbatasan Grocery Store: Mencatatkan penjualan terendah dengan distribusi data yang sangat sempit, menunjukkan skala bisnis yang paling kecil.
#
# - Anomali Supermarket Type 1: Memiliki banyak pencilan (outliers) bernilai tinggi, mengindikasikan potensi keuntungan besar pada item-item tertentu meski mediannya moderat.
#
# - Kesimpulan Hipotesis: Perbedaan distribusi yang kontras pada Boxplot memastikan Hipotesis Alternatif diterima; jenis toko berpengaruh signifikan terhadap total penjualan.

# %% [markdown]
# # Analisis PMF

# %%
# Menghitung PMF untuk kombinasi Jenis Toko (Outlet Type) dan Ukuran Toko (Outlet Size)
# Ini jauh lebih relevan dengan judul "Pengaruh Jenis Toko"
pmf_data = data_copy.groupby(['Outlet_Type', 'Outlet_Size'], observed=False).size() / len(data_copy)
pmf_data = pmf_data.reset_index(name='Probability')

print("=== Tabel PMF Kombinasi Jenis Toko & Ukuran Toko ===")
display(pmf_data)

# # Visualisasi Heatmap PMF yang relevan
# import seaborn as sns
# import matplotlib.pyplot as plt

# plt.figure(figsize=(10, 6))
# pmf_pivot = pmf_data.pivot(index='Outlet_Type', columns='Outlet_Size', values='Probability')
# sns.heatmap(pmf_pivot, annot=True, cmap='YlGnBu', fmt='.4f')
# plt.title('Heatmap PMF: Peluang Distribusi Jenis & Ukuran Toko')
# plt.show()
# Out:
# === Tabel PMF Kombinasi Jenis Toko & Ukuran Toko ===
#           Outlet_Type Outlet_Size  Probability
# 0       Grocery Store        High     0.000000
# 1       Grocery Store      Medium     0.065118
# 2       Grocery Store       Small     0.061950
# 3   Supermarket Type1        High     0.109351
# 4   Supermarket Type1      Medium     0.326763
# 5   Supermarket Type1       Small     0.218233
# 6   Supermarket Type2        High     0.000000
# 7   Supermarket Type2      Medium     0.108882
# 8   Supermarket Type2       Small     0.000000
# 9   Supermarket Type3        High     0.000000
# 10  Supermarket Type3      Medium     0.109703
# 11  Supermarket Type3       Small     0.000000

# %% [raw]
# Insight:
# - Supermarket Type 1 dengan ukuran Small merupakan kombinasi yang paling sering muncul (peluang 0.4358). Ini menunjukkan bahwa model toko tersebut adalah kontributor utama dalam jangkauan pasar BigMart.
#
# - Tipe Grocery Store secara konsisten hanya beroperasi pada ukuran Small (0.1270). Hal ini menegaskan bahwa fokus operasional tipe ini memang ditujukan untuk skala lingkungan kecil.
#
# - Untuk Supermarket Type 2 dan Type 3, distribusinya lebih terpusat pada ukuran Medium. Sepertinya ada standarisasi ukuran untuk tipe toko yang memiliki performa penjualan lebih tinggi agar operasionalnya lebih efisien.
#
# - ecara keseluruhan, ekosistem BigMart didominasi ukuran Small dan Medium. Rendahnya peluang pada ukuran High menandakan strategi yang lebih mengutamakan efisiensi ruang dan jumlah outlet yang masif.

# %% [markdown]
# # Uji statistik: Kruskal-wallis test

# %%
from scipy import stats

# 1. Menyiapkan grup data penjualan berdasarkan Jenis Toko
# Kita ambil kolom penjualan untuk tiap kategori toko
groups = []
for outlet_type in data_copy["Outlet_Type"].unique():
    # Mengambil data penjualan untuk masing-masing tipe dan hapus nilai kosong jika ada
    sales_data = data_copy[data_copy["Outlet_Type"] == outlet_type]["Item_Outlet_Sales"].dropna()
    groups.append(sales_data)

# 2. Eksekusi Kruskal-Wallis Test
h_stat, p_val = stats.kruskal(*groups)

print("=== Hasil Uji Statistik: Kruskal-Wallis Test ===")
print(f"H-statistic : {h_stat:.4f}")
print(f"p-value     : {p_val:.4f}")

# 3. Batas Signifikansi
alpha = 0.05

print("\nKesimpulan Akhir:")
if p_val < alpha:
    print("Tolak H0: Terdapat perbedaan distribusi penjualan yang signifikan antar jenis toko.")
else:
    print("Gagal Tolak H0: Tidak ada perbedaan distribusi penjualan yang signifikan antar jenis toko.")
# Out:
# === Hasil Uji Statistik: Kruskal-Wallis Test ===
# H-statistic : 2803.3609
# p-value     : 0.0000
#
# Kesimpulan Akhir:
# Tolak H0: Terdapat perbedaan distribusi penjualan yang signifikan antar jenis toko.

# %% [markdown]
# # Output Final Dataset

# %% [markdown]
# ## data sebelum siap dianalisis

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# ## data sesudah siap dianalisis

# %%
data_copy.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat        -0.682717
# 1           DRC01         5.92          Regular        -0.630182
# 2           FDN15        17.50          Low Fat        -0.671127
# 3           FDX07        19.20          Regular         0.012099
# 4           NCD19         8.93          Low Fat        -0.146632
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits And Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                8523 non-null   float64
#  2   Item_Fat_Content           8523 non-null   category
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   category
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                8523 non-null   category
#  9   Outlet_Location_Type       8523 non-null   category
#  10  Outlet_Type                8523 non-null   category
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: category(5), float64(4), int64(1), object(2)
# ...

# %%
df_feature.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat        -0.682717
# 1           DRC01         5.92          Regular        -0.630182
# 2           FDN15        17.50          Low Fat        -0.671127
# 3           FDX07        19.20          Regular         0.012099
# 4           NCD19         8.93          Low Fat        -0.146632
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits And Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
df_feature.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Item_Identifier               8523 non-null   object
#  1   Item_Weight                   8523 non-null   float64
#  2   Item_Fat_Content              8523 non-null   category
#  3   Item_Visibility               8523 non-null   float64
#  4   Item_Type                     8523 non-null   category
#  5   Item_MRP                      8523 non-null   float64
#  6   Outlet_Identifier             8523 non-null   object
#  7   Outlet_Establishment_Year     8523 non-null   int64
#  8   Outlet_Size                   8523 non-null   category
#  9   Outlet_Location_Type          8523 non-null   category
#  10  Outlet_Type                   8523 non-null   category
#  11  Item_Outlet_Sales             8523 non-null   float64
# ...

# %%
# Cek apakah kolom baru sudah masuk dalam daftar kolom
print(df_feature.columns)

# Atau tampilkan hanya kolom baru beserta ID-nya saja
display(df_feature[['Item_Identifier', 'Price_Per_Weight']].head())
# Out:
# Index(['Item_Identifier', 'Item_Weight', 'Item_Fat_Content', 'Item_Visibility',
#        'Item_Type', 'Item_MRP', 'Outlet_Identifier',
#        'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type',
#        'Outlet_Type', 'Item_Outlet_Sales', 'Price_Per_Weight',
#        'Outlet_Size_Encoded', 'Outlet_Location_Type_Encoded',
#        'Item_Fat_Content_Encoded'],
#       dtype='object')
#   Item_Identifier  Price_Per_Weight
# 0           FDA15         26.861204
# 1           DRC01          8.153581
# 2           FDN15          8.092457
# 3           FDX07          9.484115
# 4           NCD19          6.031512

# %%
data_copy.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [raw]
# Jenis Toko Berpengaruh Nyata: Hasil uji statistik membuktikan bahwa perbedaan jenis toko memberikan dampak yang signifikan terhadap hasil penjualan. Perbedaan angka di grafik bukan cuma kebetulan, tapi memang ada pola yang nyata.
#
# Supermarket Type 3 adalah tipe toko dengan rata-rata penjualan paling tinggi, sedangkan Supermarket Type 1 (Small) adalah tipe yang paling banyak jumlah cabangnya di lapangan.
#
# Saran Bisnis: Fokus pada toko ukuran Medium sangat disarankan, karena tipe ini terbukti memiliki performa penjualan yang lebih stabil dan tinggi dibandingkan tipe lainnya.

# %% [markdown]
# # Mini Project 2: Data Visualisasi & EDA

# %% [raw]
# Optimasi Pendapatan berdasarkan Karakteristik Toko:
# "Bagaimana pengaruh tipe dan ukuran outlet terhadap total penjualan, dan strategi apa yang bisa diterapkan pada outlet dengan performa rendah (seperti Grocery Stores) untuk meningkatkan profitabilitas?"

# %% [markdown]
# # Reading & Extracting Data

# %% [markdown]
# #### data sebelum siap dianalisis

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### data sesudah siap di analisis

# %%
data_copy.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat        -0.682717
# 1           DRC01         5.92          Regular        -0.630182
# 2           FDN15        17.50          Low Fat        -0.671127
# 3           FDX07        19.20          Regular         0.012099
# 4           NCD19         8.93          Low Fat        -0.146632
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits And Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### data yang sudah di encoding

# %%
df_feature.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat        -0.682717
# 1           DRC01         5.92          Regular        -0.630182
# 2           FDN15        17.50          Low Fat        -0.671127
# 3           FDX07        19.20          Regular         0.012099
# 4           NCD19         8.93          Low Fat        -0.146632
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits And Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# #### Cek type data

# %%
df.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# #### Cek missing value

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# #### Cek duplicate

# %%
data_copy.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Mengatur tema visual agar komunikatif dan bersih
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['font.size'] = 11

# %% [markdown]
# ## 1. Analisis Univariate

# %% [markdown]
# ## Kolom Numerical

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Pilih kolom numerik yang ingin divisualisasikan
numerical_cols = ["Item_Weight", "Item_Visibility", "Item_MRP", "Item_Outlet_Sales"]

# Ubah struktur data dari wide ke long format menggunakan pd.melt
# agar semua nama kolom menjadi satu kategori di kolom 'Fitur'
data_long = pd.melt(data_copy, value_vars=numerical_cols, var_name="Fitur", value_name="Nilai")

# Buat FacetGrid
# col="Fitur" artinya grafik akan dipecah berdasarkan nama kolom asli
# col_wrap=2 artinya grafik akan otomatis pindah ke baris baru setelah 2 kolom (membuat grid 2x2)
# sharex=False dan sharey=False WAJIB digunakan karena skala angka tiap kolom berbeda jauh!
g = sns.FacetGrid(data_long, col="Fitur", col_wrap=2, sharex=False, sharey=False, height=4, aspect=1.5)

# Petakan histplot ke dalam FacetGrid
g.map_dataframe(sns.histplot, x="Nilai", bins=20, kde=True, color="green")

# Percantik tampilan judul, label, dan tata letak
g.set_titles(col_template="{col_name}", weight='bold', size=12)
g.set_axis_labels("Nilai / Ukuran", "Frekuensi")

# Memberikan judul utama di atas grid grafik
plt.subplots_adjust(top=0.9)
g.figure.suptitle("Analisis Distribusi Univariat Fitur Numerik (BigMart Sales)", fontsize=15, weight='bold', y=0.98)

plt.tight_layout()
plt.show()

# %% [raw]
# Interpretasi:
# - Faktor produk yang paling mendominasi omzet cabang. Semakin tinggi atau premium harga barang yang didistribusikan, maka total nilai nominal penjualan yang tercatat di kasir akan meningkat secara signifikan.
# - Strategi format operasional toko sangat menentukan hasil penjualan. Melakukan peningkatan (upgrade) dari format toko kelontong konvensional (Grocery Store) menjadi format supermarket besar (seperti Supermarket Type 3) terbukti secara statistik mendongkrak total penjualan tahunan secara konsisten.
# - Luas fisik bangunan toko bukan jaminan utama penentu besarnya omzet. Toko berukuran sedang (Medium) yang dikelola dengan manajemen Supermarket modern jauh lebih menghasilkan penjualan dibanding toko berbangunan luas (High) yang manajemennya masih konvensional.

# %% [markdown]
# ## Kolom Kategorikal

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Pilih kolom kategorik yang kategorinya sedikit (cocok untuk Pie Chart)
pie_cols = ["Item_Fat_Content", "Outlet_Size", "Outlet_Location_Type"]

# Atur kanvas sejajar ke samping (1 baris, 3 kolom)
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Set warna gradasi hijau yang estetik untuk potongan pie chart
colors = sns.color_palette("Greens_r", 5)

for i, col in enumerate(pie_cols):
    # Hitung frekuensi tiap kategori
    data_counts = data_copy[col].value_counts()
    
    # Gambar Pie Chart di masing-masing sub-plot
    # autopct='%.1f%%' berfungsi untuk memunculkan angka persentase (1 angka di belakang koma)
    # startangle=90 agar potongan kuenya rapi dimulai dari atas
    axes[i].pie(
        data_counts, 
        labels=data_counts.index, 
        autopct='%.1f%%', 
        startangle=90, 
        colors=colors,
        wedgeprops={'edgecolor': 'white', 'linewidth': 2}, # Beri garis pembatas putih biar elegan
        textprops={'fontsize': 11, 'weight': 'bold'} # Tebalkan angka persentasenya
    )
    
    # Beri judul untuk setiap lingkaran pie
    axes[i].set_title(f"Proporsi {col}", fontsize=13, weight='bold', pad=10)

# Beri judul utama di paling atas halaman
plt.suptitle("Analisis Univariat Kategorikal: Kontribusi & Persentase Variabel", fontsize=16, weight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [raw]
# Interpretasi:
# - Mayoritas produk yang didistribusikan BigMart didominasi oleh kategori rendah lemak. Hal ini menunjukkan tren stok barang yang cenderung berorientasi pada pemenuhan kebutuhan konsumen yang peduli kesehatan (health-conscious).
# - Jaringan ritel BigMart didominasi oleh toko berukuran sedang (Medium). Perusahaan tampaknya menerapkan strategi efisiensi ruang bangunan, di mana format toko berukuran sedang dianggap paling optimal dan menjadi standar utama operasional sebagian besar cabang.
# - Ekspansi pasar BigMart berfokus pada wilayah Tier 3 (kota berkembang/suburban). Wilayah ini memiliki pangsa pasar yang paling luas dan menjadi penggerak utama jangkauan operasional bisnis ritel perusahaan dibandingkan wilayah metropolitan (Tier 1).

# %% [raw]
# Interpretasi:
# - Cabang dengan ukuran fisik sedang (Medium) menjadi tulang punggung utama pendapatan BigMart. Ukuran toko yang terlalu besar (High) justru mencatat penjualan paling rendah, menunjukkan bahwa efisiensi luas bangunan berukuran sedang jauh lebih efektif dalam menghasilkan omzet.
# - Model bisnis Supermarket Type 1 adalah mesin pencetak uang utama bagi perusahaan. Sebaliknya, format toko kelontong konvensional (Grocery Store) memberikan kontribusi yang sangat kecil, memperkuat strategi ritel untuk lebih berfokus pada pengembangan format supermarket modern.
# - Pasar di wilayah suburban atau kota berkembang (Tier 3 & Tier 2) menghasilkan akumulasi profit yang jauh lebih besar dibandingkan wilayah kota besar/metropolitan (Tier 1). Wilayah berkembang terbukti memiliki potensi daya beli massal yang sangat tinggi untuk jaringan BigMart.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Menggunakan DataFrame data_copy sesuai di notebook kamu
type_counts = data_copy['Outlet_Type'].value_counts()
total_data = len(data_copy)

# 2. Atur ukuran kanvas
plt.figure(figsize=(10, 5))

# 3. Buat Bar Chart Horizontal dengan gradasi hijau sage
# Catatan: parameter legend ditiadakan dari sini untuk menghindari AttributeError
sns.barplot(
    x=type_counts.values, 
    y=type_counts.index, 
    hue=type_counts.index,     
    palette='Greens_r',        
    edgecolor='#7FA196',
    linewidth=1.2
)

# Mematikan legend secara aman lewat fungsi Matplotlib agar tidak eror
plt.legend([], frameon=False)

# 4. Tambahkan Label Jumlah dan Persen (%) di setiap ujung batang
max_value = type_counts.values.max()
for index, value in enumerate(type_counts.values):
    percentage = (value / total_data) * 100
    plt.text(value + (max_value * 0.01), index, f'{value} outlet ({percentage:.1f}%)', 
             va='center', ha='left', fontsize=10, weight='bold', color='#2C3E50')

# 5. Desain grafik minimalis dan clean
plt.title('Distribusi Karakteristik Tipe Toko BigMart\n(Analisis Univariat)', 
          fontsize=13, weight='bold', color='#1E375A', pad=15)
plt.xlabel('Jumlah Total Outlet', fontsize=11, weight='bold', labelpad=10)
plt.ylabel('Tipe Outlet', fontsize=11, weight='bold')

plt.xlim(0, max_value * 1.25)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10, weight='bold')

sns.despine(top=True, right=True)
plt.tight_layout()
plt.show()

# %% [raw]
# Interpretasi:
#
# - Supermarket Type 1 adalah Tulang Punggung Ritel (Porsi Terbesar 👑):
# Format Supermarket Type 1 mendominasi mutlak dengan persentase 65.4% (lebih dari setengah total seluruh outlet BigMart). Ini menunjukkan bahwa model bisnis utama BigMart memang berbasis swalayan standar.
#
# - Grocery Store Berada di Posisi Kedua (12.7% 🛒):
# Toko kelontong tradisional (Grocery Store) mencakup 12.7% dari total ekosistem toko. Meskipun penjualannya paling kecil (berdasarkan grafik bar kamu sebelumnya), secara jumlah unit mereka ini cukup banyak, bebs!
#
# - Supermarket Type 2 & Type 3 Menjadi Pelengkap Pasar:
# Supermarket Type 3 (11.0%) dan Supermarket Type 2 (10.9%) memiliki jumlah proporsi yang hampir seimbang sebagai variasi format toko besar.

# %%
plt.figure(figsize=(10, 8))

# Hitung persentase tiap kategori secara langsung
total_data = len(data_copy)
item_counts = data_copy["Item_Type"].value_counts()
item_percents = (item_counts / total_data) * 100

# Gambar horizontal bar chart
ax = sns.barplot(x=item_percents.values, y=item_percents.index, color="#679267", edgecolor="black")

# Logika program untuk menempelkan teks persentase di ujung batang
for p in ax.patches:
    width = p.get_width() # mengambil panjang batang (nilai persentase)
    # Tulis teks persentasenya tepat di sebelah kanan ujung batang
    ax.text(
        width + 0.2, 
        p.get_y() + p.get_height()/2, 
        f'{width:.1f}%', 
        va='center', 
        ha='left', 
        fontsize=10, 
        weight='bold'
    )

# Atur judul dan label
plt.title("Distribusi Persentase Kategori Produk (Item Type)", fontsize=14, weight='bold', pad=15)
plt.xlabel("Persentase dari Total Produk (%)", fontsize=11)
plt.ylabel("Kategori Produk", fontsize=11)

# Batasi sumbu X agar ada ruang untuk teks persentase di sebelah kanan
plt.xlim(0, max(item_percents.values) + 2)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Analisis Bivariate

# %% [markdown]
# ### Outlet_Type vs Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

df_clean_unscaled = data_copy.copy()
df_clean_unscaled['Item_Outlet_Sales'] = df['Item_Outlet_Sales']

# Atur tema visual
sns.set_theme(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.barplot(
    data=df_clean_unscaled, 
    x='Outlet_Type', 
    y='Item_Outlet_Sales', 
    palette='Greens', 
    ci=None 
)

plt.title("Rata-Rata Penjualan Berdasarkan Tipe Toko", fontsize=14, weight='bold')
plt.xlabel("Tipe Toko (Outlet Type)", fontsize=11, weight='bold')
plt.ylabel("Rata-Rata Penjualan (dalam USD $)", fontsize=11, weight='bold')

# Atur kemiringan teks sumbu X
plt.xticks(rotation=15, fontsize=10)
plt.yticks(fontsize=10)

plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.tight_layout()
plt.show()

# %% [raw]
# Interpretasi:
#
# - Supermarket Type 3 memiliki batang tertinggi dengan rata-rata penjualan paling dominan, yaitu mencatatkan angka tertinggi mendekati $3,700.
#
# - Di posisi kedua dan ketiga, ada Supermarket Type 1 dengan rata-rata penjualan sekitar $2,300, disusul oleh Supermarket Type 2 yang berada di kisaran $2,000.
#
# - Output terkecil ditunjukkan oleh Grocery Store, di mana rata-rata penjualannya berada di posisi paling bawah dan belum menyentuh angka $500.

# %% [markdown]
# ### Item_MRP vs Item_Outlet_Sales

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6)) 

sc = plt.scatter(
    data=df_clean_unscaled, 
    x='Item_MRP', 
    y='Item_Outlet_Sales', 
    alpha=0.6,               
    c=df_clean_unscaled['Item_Outlet_Sales'], 
    cmap='YlGn'              
)

plt.title("Hubungan Antara Harga Produk (MRP) dan Total Penjualan", fontsize=12, weight='bold')
plt.xlabel("Item_MRP")
plt.ylabel("Item_Outlet_Sales")

# Menambahkan colorbar di samping kanan grafik
plt.colorbar(sc, label='Total Penjualan (Kepadatan Nilai)')

plt.show()

# %% [raw]
# Interpretasi:
#
# - Tren Korelasi Positif: Sebaran titik data bergerak naik ke arah kanan atas. Pola ini menunjukkan adanya hubungan positif, di mana peningkatan nilai Item_MRP diikuti dengan kenaikan nilai maksimum pada Item_Outlet_Sales.
#
# - Kepadatan Data & Nilai Ekstrem: Pada area MRP rendah (kiri bawah), data menumpuk padat di bawah $4,000 yang ditandai dengan warna kuning terang menuju hijau muda. Sebaliknya pada area MRP tinggi (kanan), sebaran melebar ke atas disertai beberapa data ekstrem (berwarna hijau tua pekat) yang terlihat sangat kontras menembus angka $10,000 hingga $12,000+.
#
# - Item_MRP (harga produk) berbanding lurus dengan potensi Item_Outlet_Sales (total penjualan). Meskipun mayoritas penjualan dari seluruh tingkat harga menumpuk di bawah angka $4,000, namun peluang untuk mencapai total penjualan yang sangat tinggi (ekstrem) hingga menembus rentang $10,000 - $12,000+ hanya dimiliki oleh kelompok produk dengan harga yang lebih mahal (MRP tinggi).

# %% [markdown]
# ### Item_Weight vs Item_MRP

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(9, 6))

# Menggunakan regplot dengan menonaktifkan garis tren regresi
sns.regplot(
    data=df_clean_unscaled, 
    x='Item_Weight', 
    y='Item_MRP', 
    color='#2ca25f',
    scatter_kws={'alpha': 0.5},
    fit_reg=False # KUNCINYA DI SINI BEBS, untuk menghilangkan garis merah regresi
)

plt.title("Analisis Hubungan Antara Berat Produk (Item_Weight) dan Harga (Item_MRP)", fontsize=14, weight='bold')
plt.xlabel("Berat Produk (Item_Weight)", fontsize=11)
plt.ylabel("Harga Produk (Item_MRP)", fontsize=11)

plt.grid(True, alpha=0.3) # Grid tipis
plt.tight_layout()
plt.show()

# %% [raw]
# Korelasi yang sangat lemah antara Item_Weight dan Item_MRP
#
# Interpretasi:
#
# - Pola Sebaran: Titik data menyebar merata membentuk pola kotak tanpa arah naik/turun, menandakan korelasi antara berat produk (Item_Weight) dan harga (Item_MRP) sangat lemah (mendekati nol).
#
# - Karakteristik Data: Data terdistribusi konstan pada rentang berat 5 kg hingga 21 kg (area di bawah 5 kg cenderung kosong).
#
# - Kesimpulan Awal: Baik produk ringan (5 kg) maupun berat (21 kg) memiliki rentang variasi harga yang sama luasnya, yaitu berkisar dari <$50 hingga >$250.

# %% [markdown]
# #### Uji korelasi untuk pembuktian hubungan antara Item_Weight (kg) dengan Item_MRP

# %%
# Membuat matrix korelasi khusus untuk kolom Berat dan Harga
df_clean_unscaled[['Item_Weight', 'Item_MRP']].corr()
# Out:
#              Item_Weight  Item_MRP
# Item_Weight     1.000000  0.025543
# Item_MRP        0.025543  1.000000

# %% [raw]
# - Nilai Korelasi (0.026691): Angka ini menunjukkan adanya hubungan positif yang sangat lemah (hampir mendekati nol) antara berat produk (Item_Weight) dan harga (Item_MRP).
#
# - Arti Statistik: Karena nilainya mendekati nol, secara statistik disimpulkan bahwa tidak ada hubungan linier yang signifikan di antara kedua variabel tersebut.

# %% [markdown]
# ## 3. Analisis Multivariate

# %% [markdown]
# ### Analisis Faktor yang Paling Mempengaruhi Penjualan BigMart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 8))

# 1. Mengambil semua kolom numerik utama, lalu MEMBUANG kolom tahun (Outlet_Establishment_Year)
kolom_numerik = df_clean_unscaled.select_dtypes(include=['float64', 'int64']).columns

# Solusi: Jika kolom tahun ada di dalam list, kita singkirkan dari analisis heatmap korelasi
if 'Outlet_Establishment_Year' in kolom_numerik:
    kolom_numerik = kolom_numerik.drop('Outlet_Establishment_Year')

# 2. Menghitung matriks korelasi hanya untuk fitur angka murni pilihanmu
matriks_korelasi = df_clean_unscaled[kolom_numerik].corr()

# 3. Membuat Heatmap bertema Hijau BigMart yang bersih dan estetik
sns.heatmap(
    matriks_korelasi, 
    annot=True,                # Menampilkan angka di dalam kotak
    cmap='Greens',             # Gradasi warna hijau murni sesuai tema BigMart 💚
    fmt='.2f',                 # Dua angka di belakang koma
    linewidths=0.8,            # Jarak antar kotak biar rapi dan elegan
    square=True,               # Memaksa kotak berbentuk persegi sempurna
    annot_kws={"size": 11, "weight": "bold"} # Mempertegas angka korelasi
)

# 4. Mengatur Judul dan Label Aksis
plt.title('Korelasi Multivariat: Hubungan Antar Faktor Utama Produk dan Performa Penjualan', 
          fontsize=12, weight='bold', pad=20)

plt.xticks(rotation=45, ha='right', fontsize=10, weight='bold')
plt.yticks(fontsize=10, weight='bold')

plt.tight_layout()
plt.show()

# %% [raw]
# Interpretasi:
#
# - Hubungan dengan Harga Produk: Angka penjualan (Item_Outlet_Sales) tampaknya memiliki hubungan positif paling tinggi dengan harga maksimal retail (Item_MRP) sebesar 0.57. Hal ini mengindikasikan bahwa produk yang memiliki harga jual menengah ke atas (premium) berbanding lurus dengan tingginya nilai total penjualan yang tercatat di toko.
#
# - Hubungan dengan Pajangan/Visibilitas: Angka penjualan (Item_Outlet_Sales) menunjukkan hubungan negatif dengan tingkat visibilitas produk di rak (Item_Visibility) sebesar -0.13. Pola ini mengindikasikan adanya kecenderungan terbalik, di mana produk yang ditempatkan di posisi yang terlalu mencolok atau dominan justru mengalami penurunan pada volume penjualan.
#
# - Faktor Karakteristik Fisik: Untuk faktor karakteristik lainnya seperti berat produk (Item_Weight) terhadap penjualan (0.01) maupun terhadap harga barang (0.03) tampaknya memiliki nilai korelasi yang sangat mendekati nol. Hal ini mengindikasikan bahwa dimensi fisik berupa berat barang tidak memberikan pengaruh atau hubungan yang signifikan secara langsung terhadap performa penjualan maupun penentuan harga produk.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 1. AMBIL DATA DAN AMANKAN COPY-NYA
df_heatmap_skripsi = df_clean_unscaled.copy() 

# 2. PROSES ENCODING OTOMATIS .CAT.CODES
df_heatmap_skripsi['Ukuran Toko'] = df_heatmap_skripsi['Outlet_Size'].astype('category').cat.codes
df_heatmap_skripsi['Tipe Toko'] = df_heatmap_skripsi['Outlet_Type'].astype('category').cat.codes
df_heatmap_skripsi['Harga Barang (MRP)'] = df_heatmap_skripsi['Item_MRP']
df_heatmap_skripsi['Total Penjualan'] = df_heatmap_skripsi['Item_Outlet_Sales']

# 3. SELEKSI FITUR UTAMA
kolom_analisis = ['Total Penjualan', 'Harga Barang (MRP)', 'Tipe Toko', 'Ukuran Toko']
matriks_korelasi = df_heatmap_skripsi[kolom_analisis].corr()

# 4. MEMBUAT VISUALISASI HEATMAP (Ukuran diperbesar sedikit agar muat teks normal)
plt.figure(figsize=(9, 7))
sns.heatmap(
    data=matriks_korelasi,
    annot=True,                   
    cmap='Greens',                
    fmt='.2f',                    
    linewidths=1.5,               
    square=True,                  
    annot_kws={"size": 11, "weight": "bold"},
    cbar_kws={"shrink": 0.8}
)

# 5. MENGATUR JUDUL DAN LABEL GRAFIK
plt.title('Matriks Korelasi Faktor Toko dan Performa Penjualan BigMart\n(Encoded Data)', 
          fontsize=12, weight='bold', color='#1E375A', pad=15)

plt.xticks(rotation=20, ha='right', fontsize=9, weight='bold')
plt.yticks(fontsize=9, weight='bold')

# 6. MEMBUAT LEGEND KETERANGAN BIASA & RAPI DI BAWAH (Cara Menengah)
teks_keterangan_legenda = (
    "LEGENDA & KETERANGAN ANGKA ENCODING:\n"
    "--------------------------------------------------\n"
    "[1] Tipe Toko:\n"
    "    0 = Grocery Store\n"
    "    1 = Supermarket Type 1\n"
    "    2 = Supermarket Type 2\n"
    "    3 = Supermarket Type 3\n\n"
    "[2] Ukuran Toko:\n"
    "    0 = High (Besar)\n"
    "    1 = Medium (Sedang)\n"
    "    2 = Small (Kecil)"
)

# Menaruh teks keterangan di bagian bawah agar grafiknya bersih
plt.figtext(0.1, -0.05, teks_keterangan_legenda, fontsize=10, color='#34495E', 
            bbox=dict(facecolor='#ECF0F1', alpha=1.0, boxstyle='round,pad=0.7'),
            va='top', ha='left')

# Space tambahan di bawah untuk teks agar tidak terpotong
plt.tight_layout(rect=[0, 0.1, 1, 1])

plt.show()

# %% [raw]
# Tipe Toko (0.40): Berpengaruh Kuat: Semakin modern tipe tokonya (dari Grocery Store ke Supermarket), penjualan otomatis naik drastis.
# Ukuran Toko (-0.09) : Tidak Berpengaruh: Luas atau ukuran fisik bangunan toko tidak menjamin rame atau sepinya penjualan.
# Harga Barang/MRP (0.57) : Pendorong Utama: Faktor harga barang tetap menjadi penentu omzet terbesar di semua cabang.

# %% [markdown]
# ### Pairplot Hubungan Variabel Numerik pada Dataset Bigmart

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Menentukan tema visual grafik agar minimalis dan rapi
sns.set_theme(style="ticks")

# 2. Membuat Pairplot untuk menjodohkan variabel angka utama
# Kita gunakan parameter 'hue' agar sebaran titiknya diwarnai berdasarkan tipe wilayah toko
g = sns.pairplot(
    data=df_clean_unscaled,
    vars=['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales'], # Kolom angka utama
    hue='Outlet_Location_Type', # Diwarnai berdasarkan Tingkat Wilayah
    palette=['#4A7c59', '#A3B19B', '#C1CFA1'], # Kombinasi hijau sage estetik
    plot_kws={'alpha': 0.6, 's': 30} # Mengatur transparansi dan ukuran titik agar tidak menumpuk
)

# 3. Menambahkan judul utama di paling atas matriks grafik
g.fig.suptitle('Matriks Pairplot Hubungan Variabel Numerik pada Dataset BigMart', 
               fontsize=14, fontweight='bold', color='#1E375A', y=1.02)

plt.show()

# %% [raw]
# 1. Harga Naik: Penjualan Naik (Kunci Utama)
# Hubungan Item_MRP dan Item_Outlet_Sales membentuk pola naik ke kanan atas. Ini bukti visual paling kuat bahwa semakin mahal harga barang, omzet toko otomatis semakin tinggi.
#
# 2. Visibilitas Terlalu Tinggi Malah Zonk
# Penjualan tertinggi justru menumpuk di barang dengan visibilitas (Item_Visibility) rendah-sedang. Memajang produk terlalu mencolok tidak menjamin barangnya laku.
#
# 3. Perilaku Konsumen di Semua Kota Sama
# Sebaran warna Outlet_Location_Type (Tier 1, 2, 3) tercampur rata di semua grafik. Artinya, lokasi kota tidak mengubah hubungan antar-variabel produk.

# %% [markdown]
# # Advanced EDA Techniques

# %% [markdown]
# ##  Cross Tabulation

# %% [markdown]
# #### a. Membuat cross-tab Pengaruh Tipe dan Lokasi Toko terhadap Total Omset Penjualan

# %%
# Tipe Toko vs Lokasi

ct_lokasi = pd.crosstab(
    df_clean_unscaled['Outlet_Type'], 
    df_clean_unscaled['Outlet_Location_Type'], 
    values=df_clean_unscaled['Item_Outlet_Sales'], 
    aggfunc='sum', margins=True, margins_name='Total Omset'
).fillna(0)

ct_lokasi.style.format("{:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_7117d_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Outlet_Location_Type</th>
#       <th class="col_heading level0 col0" >Tier 1</th>
#       <th class="col_heading level0 col1" >Tier 2</th>
#       <th class="col_heading level0 col2" >Tier 3</th>
#       <th class="col_heading level0 col3" >Total Omset</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Outlet_Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7117d_level0_row0" class="row_heading level0 row0" >Grocery Store</th>
#       <td id="T_7117d_row0_col0" class="data row0 col0" >179,694.09</td>
#       <td id="T_7117d_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_7117d_row0_col2" class="data row0 col2" >188,340.17</td>
# ...

# %% [raw]
# Interpretasi:
#
# - Grocery Store: Total penjualan di tipe toko ini adalah $368,034.27. Angka paling tinggi di lokasi ini disumbang oleh wilayah Tier 3 ($188,340.17).
#
# - Supermarket Type1: Tipe toko ini punya angka penjualan paling tinggi di antara semua lokasi, yaitu sebanyak $12,917,342.26. Penjualan paling banyak di sini berasal dari wilayah Tier 2 ($6,472,313.71).
#
# - Supermarket Type2: Total penjualan di tipe toko ini adalah $1.851.822,83. Angka ini murni hanya berasal dari wilayah Tier 3 ($1.851.822,83) karena tidak beroperasi di wilayah lain.
#
# - Supermarket Type3: Total penjualan di tipe toko ini adalah $3,453,926.05. Angka ini juga murni seluruhnya disumbang oleh wilayah Tier 3 ($3,453,926.05).
#
# - Kesimpulannya, wilayah Tier 3 adalah yang mengumpulkan angka penjualan paling banyak secara keseluruhan di tabel, yaitu sebanyak $7,636,752.63. Dan wilayah Tier 1 adalah yang paling sedikit mengumpulkan angka penjualan secara keseluruhan di tabel, yaitu hanya $4,482,059.07.

# %% [markdown]
# #### b. Pemetaan Kategori Barang di Berbagai Tipe Toko

# %%
# Pemetaan Kategori Barang di Berbagai Tipe Toko
crosstab_tipe_kategori = pd.crosstab(
    index=df_clean_unscaled['Item_Type'],                   # Baris: Jenis Barang (Termasuk Household dll)
    columns=df_clean_unscaled['Outlet_Type'],               # Kolom: Grocery Store, Supermarket Type 1, 2, 3
    values=df_clean_unscaled['Item_Outlet_Sales'],          # Angka: Total Penjualan
    aggfunc='sum', margins=True, margins_name='Total Penjualan'
).fillna(0)

# Menampilkan dengan format mata uang yang rapi
crosstab_tipe_kategori.style.format("{:,.2f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6afd9_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Outlet_Type</th>
#       <th class="col_heading level0 col0" >Grocery Store</th>
#       <th class="col_heading level0 col1" >Supermarket Type1</th>
#       <th class="col_heading level0 col2" >Supermarket Type2</th>
#       <th class="col_heading level0 col3" >Supermarket Type3</th>
#       <th class="col_heading level0 col4" >Total Penjualan</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Item_Type</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6afd9_level0_row0" class="row_heading level0 row0" >Baking Goods</th>
#       <td id="T_6afd9_row0_col0" class="data row0 col0" >24,827.02</td>
# ...

# %% [markdown]
# ## Random Sampling

# %% [markdown]
# #### a. mengambil 10 data secara acak

# %%
df_sample = df_clean_unscaled.sample(n=10, random_state=42)
df_sample
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7503           FDI28    14.300000          Low Fat        -0.516009
# 2957           NCM17     7.930000          Low Fat         0.213033
# 7031           FDC14    14.500000          Regular        -0.271889
# 1084           DRC36    12.857645          Regular        -0.215729
# 856            FDS27    10.195000          Regular        -0.741115
# 4304           DRK12     9.500000          Low Fat        -0.261511
# 2132           FDO25    12.857645          Low Fat         1.118660
# 1385           FDB58    10.500000          Regular        -0.723300
# 5239           FDY48    14.000000          Low Fat        -0.556143
# 6516           NCP42     8.510000          Low Fat        -0.680619
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 7503        Frozen Foods   79.4302            OUT013
# 2957  Health And Hygiene   42.7086            OUT046
# 7031              Canned   42.0454            OUT049
# ...

# %% [markdown]
# #### b. mengambil random state 10% dari dataset

# %%
data_sample = df_clean_unscaled.sample(frac=0.1, random_state=42)

print(f"JUmlah baris sampel (10%): {len(data_sample)}")
data_sample.head()
# Out:
# JUmlah baris sampel (10%): 852
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7503           FDI28    14.300000          Low Fat        -0.516009
# 2957           NCM17     7.930000          Low Fat         0.213033
# 7031           FDC14    14.500000          Regular        -0.271889
# 1084           DRC36    12.857645          Regular        -0.215729
# 856            FDS27    10.195000          Regular        -0.741115
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 7503        Frozen Foods   79.4302            OUT013
# 2957  Health And Hygiene   42.7086            OUT046
# 7031              Canned   42.0454            OUT049
# 1084         Soft Drinks  173.7054            OUT027
# 856                 Meat  197.5110            OUT035
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 7503                       1987        High               Tier 3
# 2957                       1997       Small               Tier 1
# ...

# %% [raw]
# Tujuannya:
#
# - Melihat Gambaran Umum Data Secara Ringkas: Mengambil sebagian kecil baris data secara acak untuk melihat contoh potongan data asli secara cepat, tanpa harus membuka belasan ribu baris data sekaligus yang bisa membuat tampilan layar Jupyter Notebook penuh.
# - Memeriksa Konsistensi Data: Memastikan bahwa struktur kolom dan variasi isi data (seperti kategori produk Item_Type dan tipe lokasi Outlet_Location_Type) tetap terjaga dengan baik walaupun datanya diperkecil.

# %% [raw]
# Interpretasi:
#
# - Keberhasilan Pengecekan Ukuran Data: Berdasarkan hasil query .shape, proses pengambilan sampel acak telah berhasil memotong data menjadi lebih ringkas, yaitu tepat sebanyak 100 baris dan 12 kolom.
#
# - Validasi Keutuhan Tipe Data: Melalui ringkasan tabel .info(), terbukti bahwa seluruh 12 kolom tidak mengalami perubahan format atau tipe data. Kolom kategorikal (seperti Item_Fat_Content, Item_Type, Outlet_Size, Outlet_Location_Type, dan Outlet_Type) tetap tersimpan sebagai category, kolom numerik desimal (Item_Weight, Item_Visibility, Item_MRP, Item_Outlet_Sales) tetap konsisten berupa float64, dan kolom tahun berupa int64.
#
# - Deteksi Data Kosong (Missing Values): Hasil query .info() juga berhasil menangkap informasi penting bahwa seluruh 12 kolom memiliki 100 baris yang terisi penuh (100 non-null). Hal ini menunjukkan bahwa proses data cleaning yang dilakukan sebelumnya telah berhasil 100% membersihkan data kosong, sehingga tidak ada missing value bawaan yang lolos ke dalam sampel.
#
# - Keterwakilan Nilai Sampel: Pada contoh 5 baris teratas (.head()), data acak yang muncul berhasil menampilkan variasi karakteristik produk yang nyata. Contohnya, ada produk makanan cepat saji murah dengan harga $79.43 (Frozen Foods di baris indeks 7503) hingga produk daging premium yang harganya mencapai $197.51 (Meat di baris indeks 856).

# %% [markdown]
# ## Grouping

# %% [markdown]
# #### a. Menghitung total omset berdasarkan Ukuran Toko (Outlet_Size)

# %% [raw]
# Analisis Ukuran Toko vs Omset Penjualan
#
# Mengelompokkan `Outlet_Size` terhadap `Item_Outlet_Sales` untuk melihat performa kapasitas toko:
#
# Toko berukuran apa sih yang sebenarnya jadi mesin pencetak uang utama BigMart? Apakah toko raksasa (High) yang serba ada, atau jangan-jangan toko kecil (Small) yang tersebar di banyak tempat justru lebih mendominasi omset?

# %%
# Menghitung total penjualan untuk setiap ukuran toko
df_clean_unscaled.groupby('Outlet_Size')['Item_Outlet_Sales'].sum().round(2)
# Out:
# Outlet_Size
# High       2142663.58
# Medium    11882249.64
# Small      4566212.20
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# #### b. Melihat Rata-Rata Harga Barang (Item_MRP) Berdasarkan Kategori (Item_Type)

# %% [raw]
# Analisis Strategi Nilai Produk (Pricing Strategy)
#
# Mengelompokkan `Item_Type` terhadap `Item_MRP` untuk melihat rata-rata harga tiap kategori:
#
# Kategori produk mana sih yang secara global dibanderol paling mahal di rak BigMart? Apakah produk kebutuhan rumah tangga jangka panjang (Household), atau justru produk konsumsi harian yang harganya lebih ramah di kantong?

# %%
df_clean_unscaled.groupby('Item_Type')['Item_MRP'].mean().round(2)
# Out:
# Item_Type
# Baking Goods             126.38
# Breads                   140.95
# Breakfast                141.79
# Canned                   139.76
# Dairy                    148.50
# Frozen Foods             138.50
# Fruits And Vegetables    144.58
# Hard Drinks              137.08
# Health And Hygiene       130.82
# Household                149.42
# Meat                     139.88
# Others                   132.85
# Seafood                  141.84
# Snack Foods              146.19
# Soft Drinks              131.49
# Starchy Foods            147.84
# Name: Item_MRP, dtype: float64

# %% [markdown]
# #### c. Melihat Total Omset Berdasarkan Wilayah Toko (Outlet_Location_Type)

# %% [raw]
# Analisis Klasifikasi Wilayah vs Total Cuan
#
# Mengelompokkan `Outlet_Location_Type` terhadap `Item_Outlet_Sales` untuk melihat peta kantong-kantong keuntungan:
#
# Di wilayah (Tier) mana sih konsumen biasanya paling boros belanja? Apakah di kota besar yang serba modern (Tier 1), atau justru di wilayah berkembang (Tier 3) yang perputaran uangnya diam-diam membludak?

# %%
df_clean_unscaled.groupby('Outlet_Location_Type')['Item_Outlet_Sales'].sum().round(2)
# Out:
# Outlet_Location_Type
# Tier 1    4482059.07
# Tier 2    6472313.71
# Tier 3    7636752.63
# Name: Item_Outlet_Sales, dtype: float64

# %% [markdown]
# #### d. Menghitung Rata-Rata Tingkat Visibilitas (Item_Visibility) Berdasarkan Tipe Toko (Outlet_Type)

# %% [raw]
# Analisis Efektivitas Display dan Visibilitas Produk
#
# Mengelompokkan `Outlet_Type` terhadap `Item_Visibility` untuk melihat seberapa mencolok peletakan barang:
#
# Apakah di toko kelontong biasa (Grocery Store) pajangan produknya dibuat jauh lebih padat dan mencolok mata konsumen karena keterbatasan space, dibandingkan dengan supermarket besar yang areanya luas dan rapi?

# %%
df_clean_unscaled.groupby('Outlet_Type')['Item_Visibility'].mean().round(4)
# Out:
# Outlet_Type
# Grocery Store        0.8119
# Supermarket Type1    0.1009
# Supermarket Type2    0.1142
# Supermarket Type3    0.0695
# Name: Item_Visibility, dtype: float64

# %% [markdown]
# ## Filtering

# %% [markdown]
# ### a. menampilkan outlet yang berukuran medium

# %%
# Mengambil data toko yang ukurannya hanya 'Medium'
df_size_medium = df_clean_unscaled[df_clean_unscaled['Outlet_Size'] == 'Medium']

print(f"Jumlah data setelah filter ukuran Medium: {len(df_size_medium)} baris")
df_size_medium.head()
# Out:
# Jumlah data setelah filter ukuran Medium: 5203 baris
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15        9.300          Low Fat        -0.682717
# 1           DRC01        5.920          Regular        -0.630182
# 2           FDN15       17.500          Low Fat        -0.671127
# 3           FDX07       19.200          Regular         0.012099
# 5           FDP36       10.395          Regular         0.070066
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits And Vegetables  182.0950            OUT010
# 5           Baking Goods   51.4008            OUT018
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# ### b. menampilkan supermarket yang bertipe 1 & 2

# %%
# Mengambil data hanya untuk tipe Supermarket 2 & 3
df_only_supermarket = df_clean_unscaled[df_clean_unscaled['Outlet_Type'].isin(['Supermarket Type2', 'Supermarket Type3'])]

print(f"Jumlah data tipe Supermarket: {len(df_only_supermarket)} baris")
df_only_supermarket.head()
# Out:
# Jumlah data tipe Supermarket: 1863 baris
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 1            DRC01     5.920000          Regular        -0.630182
# 5            FDP36    10.395000          Regular         0.070066
# 7            FDP10    12.857645          Low Fat         1.129034
# 16           NCB42    11.800000          Low Fat        -0.803875
# 18           DRI11    12.857645          Low Fat        -0.386938
#
#              Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 1          Soft Drinks   48.2692            OUT018                       2009
# 5         Baking Goods   51.4008            OUT018                       2009
# 7          Snack Foods  107.7622            OUT027                       1985
# 16  Health And Hygiene  115.3492            OUT018                       2009
# 18         Hard Drinks  113.2834            OUT027                       1985
#
# ...

# %% [markdown]
# ### c. menampilkan produk dengan harga > 150 USD & posisinya paling strategis

# %%
# Memfilter produk yang harganya mahal DAN tingkat visibilitasnya tinggi
df_high_value = df_clean_unscaled[
    (df_clean_unscaled['Item_MRP'] > 150) & 
    (df_clean_unscaled['Item_Visibility'] > 0.1)
]

print(f"Jumlah data produk premium & mencolok: {len(df_high_value)} baris")
df_high_value.head()
# Out:
# Jumlah data produk premium & mencolok: 1724 baris
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 9            FDU28        19.20          Regular         0.592118
# 14           FDF32        16.35          Low Fat         0.162438
# 19           FDU02        13.35          Low Fat         0.722891
# 20           FDN22        18.85          Regular         1.303350
# 34           DRH01        17.50          Low Fat         0.648288
#
#                 Item_Type  Item_MRP Outlet_Identifier  \
# 9            Frozen Foods  187.8214            OUT017
# 14  Fruits And Vegetables  196.4426            OUT013
# 19                  Dairy  230.5352            OUT035
# 20            Snack Foods  250.8724            OUT013
# 34            Soft Drinks  174.8738            OUT046
#
#     Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 9                        2007      Medium               Tier 2
# ...

# %% [markdown]
# ### d. Memfilter beberapa kategori makanan pilihan dengan harga di atas $100

# %%
# Memfilter beberapa kategori makanan pilihan dengan harga di atas $100
df_premium_food = df_clean_unscaled[
    (df_clean_unscaled['Item_Type'].isin(['Snack Foods', 'Frozen Foods', 'Canned'])) & 
    (df_clean_unscaled['Item_MRP'] > 100)
]

print(f"Jumlah data produk makanan pilihan premium: {len(df_premium_food)} baris")
df_premium_food.head()
# Out:
# Jumlah data produk makanan pilihan premium: 1945 baris
#    Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 7            FDP10    12.857645          Low Fat         1.129034
# 9            FDU28    19.200000          Regular         0.592118
# 13           FDS46    17.600000          Regular        -0.175236
# 20           FDN22    18.850000          Regular         1.303350
# 24           FDR28    13.850000          Regular        -0.522567
#
#        Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 7    Snack Foods  107.7622            OUT027                       1985
# 9   Frozen Foods  187.8214            OUT017                       2007
# 13   Snack Foods  119.6782            OUT046                       1997
# 20   Snack Foods  250.8724            OUT013                       1987
# 24  Frozen Foods  165.0210            OUT046                       1997
#
#    Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %% [markdown]
# ## Sorting

# %% [markdown]
# ### a. Kategori Produk (Item Type) dengan Total Penjualan Tertinggi

# %%
# Mengelompokkan berdasarkan Item_Type dan menjumlahkan total penjualan
item_type_sales = df_clean_unscaled.groupby('Item_Type', observed=False).agg(
    Total_Penjualan_Kategori=('Item_Outlet_Sales', 'sum')
).sort_values(by='Total_Penjualan_Kategori', ascending=False).reset_index().head()

item_type_sales
# Out:
#                Item_Type  Total_Penjualan_Kategori
# 0  Fruits And Vegetables              2.820060e+06
# 1            Snack Foods              2.732786e+06
# 2              Household              2.055494e+06
# 3           Frozen Foods              1.825735e+06
# 4                  Dairy              1.522594e+06

# %% [markdown]
# ### b. Tipe Outlet dengan Omzet Tertinggi

# %%
# Mengelompokkan berdasarkan Outlet_Type dan menjumlahkan total penjualan
# Mengurutkan dari total penjualan terbesar ke terkecil (Top 5 Tipe Format Toko Paling Cuan)

outlet_sales = df_clean_unscaled.groupby('Outlet_Type', observed=False).agg(
    Total_Penjualan_Tipe=('Item_Outlet_Sales', 'sum')
).sort_values(by='Total_Penjualan_Tipe', ascending=False).reset_index().head()


outlet_sales
# Out:
#          Outlet_Type  Total_Penjualan_Tipe
# 0  Supermarket Type1          1.291734e+07
# 1  Supermarket Type3          3.453926e+06
# 2  Supermarket Type2          1.851823e+06
# 3      Grocery Store          3.680343e+05

# %% [markdown]
# # Business Visualization

# %% [markdown]
# ## Insight 1: Strategi Optimalisasi Pasokan & Kontribusi Pendapatan Gerai

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Mengatur kanvas: 1 baris, 2 kolom (dipisah total)
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# CHART LERBATAS 1 (KIRI): Khusus Membedah Jenis Format Toko (Outlet Type)
sns.barplot(
    data=df_clean_unscaled, 
    x='Outlet_Type', 
    y='Item_Outlet_Sales', 
    estimator=sum,       # Total penjualan
    ci=None, 
    palette='Greens_d',
    ax=axes[0]
)
axes[0].ticklabel_format(style='plain', axis='y')
axes[0].set_title('Total Penjualan Berdasarkan Jenis Format Toko', fontsize=12, fontweight='bold', pad=10)
axes[0].set_xlabel('Jenis Format Toko', fontsize=10)
axes[0].set_ylabel('Total Penjualan ($)', fontsize=10)
axes[0].tick_params(axis='x', rotation=15)

# CHART LERBATAS 2 (KANAN): Khusus Membedah Ukuran Fisik Toko (Outlet Size)
sns.barplot(
    data=df_clean_unscaled, 
    x='Outlet_Size', 
    y='Item_Outlet_Sales', 
    estimator=sum,       # Total penjualan
    ci=None, 
    palette='Greens_r',   
    order=['Small', 'Medium', 'High'], # Mengurutkan ukuran dari kecil ke besar
    ax=axes[1]
)
axes[1].ticklabel_format(style='plain', axis='y')
axes[1].set_title('Total Penjualan Berdasarkan Ukuran Fisik Toko', fontsize=12, fontweight='bold', pad=10)
axes[1].set_xlabel('Ukuran Fisik Toko', fontsize=10)
axes[1].set_ylabel('Total Penjualan ($)', fontsize=10)

# FINISHING
plt.suptitle('Analisis Terpisah Faktor Penentu Kesuksesan Penjualan BigMart', fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Insight 2: Analisis Karakteristik Nominal Belanja Konsumen Per Transaksi Berdasarkan Jenis Format Toko

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Mengatur ukuran kanvas (figsize) agar proporsional dan jelas saat dipindah ke slide
plt.figure(figsize=(10, 6))

# Membuat Box Plot untuk melihat karakteristik "Isi Kantong Belanja" konsumen per transaksi
# Menggunakan data sebelum di-scale (df_clean_unscaled) agar nominal dolarnya asli
sns.boxplot(
    data=df_clean_unscaled,
    x='Outlet_Type',
    y='Item_Outlet_Sales',
    palette=['#4A7c59', '#68BB59', '#A3B19B', '#C1CFA1'] # Variasi warna hijau sage yang elegan
)

# Mematikan format angka ilmiah (seperti 1e4) pada sumbu Y agar menampilkan nominal dolar asli
plt.ticklabel_format(style='plain', axis='y')

# Mengatur Judul Grafik dan Label Sumbu dengan gaya formal untuk sidang skripsi
plt.title('Karakteristik Nominal Belanja Konsumen Per Transaksi Berdasarkan Jenis Format Toko', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Jenis Format Toko (Outlet Type)', fontsize=12)
plt.ylabel('Nilai Transaksi Per Belanja ($)', fontsize=12)

# Memutar teks label pada sumbu X sebesar 15 derajat agar nama format toko terbaca rapi
plt.xticks(rotation=15)

# Menyempurnakan tata letak agar tidak ada teks atau komponen grafik yang terpotong
plt.tight_layout()

plt.show()

# %% [markdown]
# # Insight & Kesimpulan

# %% [raw]
# - Melalui Analisis Korelasi Heatmap, Tipe Outlet terbukti memiliki korelasi positif moderat sebesar 0.40 terhadap penjualan. Artinya, semakin modern tipe tokonya (Grocery Store jadi Supermarket), penjualan otomatis naik drastis.
# - Variasi harga barang di rak (Item_MRP) memiliki korelasi positif terkuat (0.57). Ini menandakan nilai produk yang dijual adalah pendorong utama omzet.
# - Format toko kelontong tradisional (Grocery Store) mencatat rata-rata penjualan terendah karena keterbatasan variasi produk bernilai tinggi, bukan semata-mana karena ukuran fisiknya.

# %% [raw]
# - Berdasarkan Uji Kruskal-Wallis pada variabel Tipe Outlet, didapatkan nilai p-value 0.0000 (di bawah 0.05). Hal ini membuktikan secara mutlak bahwa Tipe Outlet memiliki pengaruh yang sangat signifikan terhadap total penjualan BigMart (H1 diterima).
# - Melalui Analisis Korelasi Heatmap, Tipe Outlet terbukti memiliki korelasi positif moderat sebesar 0.40 terhadap penjualan. Artinya, semakin modern tipe tokonya (Grocery Store jadi Supermarket), penjualan otomatis naik drastis.

# %% [raw]
# 1. ukuran outlet tidak berpengaruh terhadap total sales/penjualan/omzet
# 2. item_MRP berpengaruh terhadap total sales/penjualan/omzet
# 3. Tapi lokasi ngaruh ga??
# 4. Apakah data nya lebih price sensitif
